# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

import torch 
import torch.nn as nn 
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.optim as optim 
from datasets import load_dataset 

import os 
import h5py
from tqdm import tqdm
import pyarrow
import time 
import json 

import sys 
sys.path.append('../code')
import utils
import model 
import loss 
from custom_dataset import CustomDataset
import train

# %%
(gene_dict, dataset_gene, dataset_gene_ids) = utils.generate_gene_dic()

tokenizer = utils.tokenizer_v1(gene_dict= gene_dict,
                         dataset_gene= dataset_gene,
                         dataset_gene_ids= dataset_gene_ids) 

vocab_size = tokenizer.vocab_size
print(vocab_size)

tokenizer.add_token(token = '<cls>')
tokenizer.add_token(token = '<pad>')
#tokenizer.gene_dict['<cls>'] = vocab_size
print(tokenizer.vocab_size)
print(tokenizer.gene_dict['<cls>']) 
print(tokenizer.gene_dict['<pad>'])
# Out:
# 33524
# 33526
# 33524
# 33525

# %%
collate_fn = utils.collater(tokenizer= tokenizer, max_expression= 100, mask_ratio = 0.1, 
                            max_num = 2000,  rho = 0.1, pad_idx = tokenizer.gene_dict['<pad>'])

# %%
#dataset_1  = load_dataset(path = 'mus_brain', cache_dir = 'huggingface_cache')
dataset_1 = load_dataset(path = '/work/sunrui/pretrain_dataset/allen_2021_data',
                         cache_dir = '/work/sunrui/huggingface')
dataset_2 = load_dataset(path = '/work/sunrui/pretrain_dataset/allen_2023_data', 
                         cache_dir = '/work/sunrui/huggingface') 

dataset_1 = dataset_1['train'].select(range(3000)).train_test_split(test_size = 0.05)
dataset_2= dataset_2['train'].select(range(3000)).train_test_split(test_size = 0.05)

train_dataset_1, test_dataset_1 = dataset_1['train'], dataset_2['test']
train_dataset_2, test_dataset_2 = dataset_2['train'], dataset_2['test']

train_dataset = CustomDataset([train_dataset_1, train_dataset_2]) 
test_dataset = CustomDataset([test_dataset_1, test_dataset_2])
# Out:
# Resolving data files:   0%|          | 0/117 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/117 [00:00<?, ?it/s]
# /home/sunrui/anaconda3/envs/pytorch/lib/python3.10/site-packages/datasets/table.py:1392: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Resolving data files:   0%|          | 0/419 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/412 [00:00<?, ?it/s]

# %%
count_embedding_num = 104
gene_embedding_num = tokenizer.vocab_size

d_model = 256
gene_padding_idx = tokenizer.gene_dict['<pad>']
count_padding_idx = 103
n_head = 8
dim_ffn = 4*d_model
dropout = 0.1
layer_norm_eps =1e-5
batch_first = True
norm_first = False
num_layers = 8
norm = None
num_hiddens = 256

my_model = model.sc_pretrain(count_embedding_num,
                 gene_embedding_num,
                 d_model,
                 gene_padding_idx,
                 count_padding_idx,
                 n_head,
                 dim_ffn,
                 dropout,
                 layer_norm_eps,
                 batch_first,
                 norm_first,
                 num_layers,
                 norm,
                 num_hiddens)

# %%
# 创建 DataLoader 实例
batch_size = 4
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn= collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn= collate_fn)

# %%
pretrain_loss = loss.pretrain_loss()

my_model = train.train_multi_epoch(my_model, 
                train_loader,
                test_loader,
                pretrain_loss, 
                #optimizer = optim.SGD(my_model.parameters(), lr=1e-4, momentum=0.9),
               optimizer = optim.Adam(my_model.parameters(), lr = 5e-5, weight_decay=0.01)
                device = 'cuda',
                gradient_accumulation_steps = 8,
                save_steps = 100,
                save_dir = 'test_1',
                epochs = 5)
# Out:
# epochs: 0 begin training:================================================================================
# /work/sunrui/pretrain_project/notebook/../code/utils.py:174: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1678411187366/work/torch/csrc/utils/tensor_new.cpp:245.)
#   batch_data['counts_0'] = torch.tensor(batch_data['counts_0'], dtype = torch.int)
# Step 1, Loss: 6.3907, Exp_loss : 5.1032, Clip_loss ; 1.2875
# Step 2, Loss: 6.3051, Exp_loss : 5.0146, Clip_loss ; 1.2906
# Step 3, Loss: 6.1143, Exp_loss : 4.8274, Clip_loss ; 1.2869
# Step 4, Loss: 5.8445, Exp_loss : 4.5789, Clip_loss ; 1.2656
# Step 5, Loss: 5.5032, Exp_loss : 4.2857, Clip_loss ; 1.2175
# Step 6, Loss: 5.3384, Exp_loss : 4.0509, Clip_loss ; 1.2874
# Step 7, Loss: 4.9877, Exp_loss : 3.7539, Clip_loss ; 1.2338
# Step 8, Loss: 4.7551, Exp_loss : 3.5503, Clip_loss ; 1.2048
# Step 9, Loss: 4.5518, Exp_loss : 3.4357, Clip_loss ; 1.1160
# Step 10, Loss: 4.3712, Exp_loss : 3.2551, Clip_loss ; 1.1162
# Step 11, Loss: 4.4349, Exp_loss : 3.2084, Clip_loss ; 1.2265
# Step 12, Loss: 4.1086, Exp_loss : 3.1109, Clip_loss ; 0.9977
# Step 13, Loss: 3.9702, Exp_loss : 2.9074, Clip_loss ; 1.0629
# Step 14, Loss: 3.8383, Exp_loss : 2.9057, Clip_loss ; 0.9325
# Step 15, Loss: 3.7225, Exp_loss : 2.9009, Clip_loss ; 0.8216
# Step 16, Loss: 3.7319, Exp_loss : 2.8022, Clip_loss ; 0.9297
# Step 17, Loss: 3.5798, Exp_loss : 2.7441, Clip_loss ; 0.8357
# Step 18, Loss: 3.4135, Exp_loss : 2.6478, Clip_loss ; 0.7657
# Step 19, Loss: 3.5351, Exp_loss : 2.6855, Clip_loss ; 0.8496
# Step 20, Loss: 3.2448, Exp_loss : 2.6309, Clip_loss ; 0.6139
# Step 21, Loss: 3.3640, Exp_loss : 2.7323, Clip_loss ; 0.6317
# Step 22, Loss: 3.6734, Exp_loss : 2.8066, Clip_loss ; 0.8668
# Step 23, Loss: 3.2096, Exp_loss : 2.5983, Clip_loss ; 0.6113
# Step 24, Loss: 3.2323, Exp_loss : 2.6054, Clip_loss ; 0.6269
# Step 25, Loss: 3.2960, Exp_loss : 2.5090, Clip_loss ; 0.7870
# Step 26, Loss: 3.0644, Exp_loss : 2.4664, Clip_loss ; 0.5980
# Step 27, Loss: 3.0780, Exp_loss : 2.5192, Clip_loss ; 0.5588
# Step 28, Loss: 3.3077, Exp_loss : 2.5805, Clip_loss ; 0.7272
# Step 29, Loss: 3.3237, Exp_loss : 2.5952, Clip_loss ; 0.7286
# Step 30, Loss: 3.0483, Exp_loss : 2.5264, Clip_loss ; 0.5219
# Step 31, Loss: 3.3881, Exp_loss : 2.6778, Clip_loss ; 0.7103
# Step 32, Loss: 3.3279, Exp_loss : 2.6525, Clip_loss ; 0.6754
# Step 33, Loss: 3.0762, Exp_loss : 2.5712, Clip_loss ; 0.5050
# Step 34, Loss: 3.0749, Exp_loss : 2.5215, Clip_loss ; 0.5534
# Step 35, Loss: 3.1542, Exp_loss : 2.6293, Clip_loss ; 0.5248
# Step 36, Loss: 3.2097, Exp_loss : 2.6327, Clip_loss ; 0.5770
# Step 37, Loss: 3.1467, Exp_loss : 2.5229, Clip_loss ; 0.6238
# Step 38, Loss: 3.0423, Exp_loss : 2.5008, Clip_loss ; 0.5415
# Step 39, Loss: 2.9802, Exp_loss : 2.4568, Clip_loss ; 0.5234
# Step 40, Loss: 3.1145, Exp_loss : 2.4564, Clip_loss ; 0.6580
# Step 41, Loss: 3.0914, Exp_loss : 2.6055, Clip_loss ; 0.4860
# Step 42, Loss: 2.8427, Exp_loss : 2.5158, Clip_loss ; 0.3269
# Step 43, Loss: 2.9086, Exp_loss : 2.4884, Clip_loss ; 0.4202
# Step 44, Loss: 3.0147, Exp_loss : 2.4153, Clip_loss ; 0.5994
# Step 45, Loss: 2.8144, Exp_loss : 2.3736, Clip_loss ; 0.4409
# Step 46, Loss: 2.7073, Exp_loss : 2.3311, Clip_loss ; 0.3761
# Step 47, Loss: 2.9341, Exp_loss : 2.4710, Clip_loss ; 0.4631
# Step 48, Loss: 3.0636, Exp_loss : 2.5478, Clip_loss ; 0.5159
# Step 49, Loss: 3.1315, Exp_loss : 2.5566, Clip_loss ; 0.5749
# Step 50, Loss: 3.0146, Exp_loss : 2.5310, Clip_loss ; 0.4836
# Step 51, Loss: 2.9786, Exp_loss : 2.4692, Clip_loss ; 0.5094
# Step 52, Loss: 3.0036, Exp_loss : 2.4737, Clip_loss ; 0.5299
# Step 53, Loss: 2.9719, Exp_loss : 2.4164, Clip_loss ; 0.5555
# Step 54, Loss: 3.0827, Exp_loss : 2.4855, Clip_loss ; 0.5971
# Step 55, Loss: 3.0649, Exp_loss : 2.5700, Clip_loss ; 0.4950
# Step 56, Loss: 3.0268, Exp_loss : 2.4806, Clip_loss ; 0.5462
# Step 57, Loss: 2.9057, Exp_loss : 2.4130, Clip_loss ; 0.4927
# Step 58, Loss: 2.9283, Exp_loss : 2.4098, Clip_loss ; 0.5185
# Step 59, Loss: 2.9099, Exp_loss : 2.4072, Clip_loss ; 0.5027
# Step 60, Loss: 3.1538, Exp_loss : 2.5618, Clip_loss ; 0.5920
# Step 61, Loss: 2.7843, Exp_loss : 2.3305, Clip_loss ; 0.4537
# Step 62, Loss: 2.9916, Exp_loss : 2.4629, Clip_loss ; 0.5287
# Step 63, Loss: 3.0680, Exp_loss : 2.5802, Clip_loss ; 0.4878
# Step 64, Loss: 2.9101, Exp_loss : 2.3762, Clip_loss ; 0.5339
# Step 65, Loss: 2.8727, Exp_loss : 2.4912, Clip_loss ; 0.3814
# Step 66, Loss: 2.8434, Exp_loss : 2.3964, Clip_loss ; 0.4470
# Step 67, Loss: 2.8750, Exp_loss : 2.4451, Clip_loss ; 0.4299
# Step 68, Loss: 3.0275, Exp_loss : 2.4548, Clip_loss ; 0.5727
# Step 69, Loss: 2.9981, Exp_loss : 2.5366, Clip_loss ; 0.4616
# Step 70, Loss: 2.9159, Exp_loss : 2.3635, Clip_loss ; 0.5524
# Step 71, Loss: 2.9616, Exp_loss : 2.5208, Clip_loss ; 0.4408
# Step 72, Loss: 3.0574, Exp_loss : 2.5137, Clip_loss ; 0.5438
# Step 73, Loss: 3.0364, Exp_loss : 2.4664, Clip_loss ; 0.5700
# Step 74, Loss: 2.8554, Exp_loss : 2.3242, Clip_loss ; 0.5311
# Step 75, Loss: 3.0413, Exp_loss : 2.4392, Clip_loss ; 0.6021
# Step 76, Loss: 3.0164, Exp_loss : 2.5912, Clip_loss ; 0.4252
# Step 77, Loss: 3.0602, Exp_loss : 2.4899, Clip_loss ; 0.5704
# Step 78, Loss: 2.6726, Exp_loss : 2.3671, Clip_loss ; 0.3055
# Step 79, Loss: 2.8303, Exp_loss : 2.4970, Clip_loss ; 0.3334
# Step 80, Loss: 2.8015, Exp_loss : 2.4941, Clip_loss ; 0.3075
# Step 81, Loss: 2.7379, Exp_loss : 2.4276, Clip_loss ; 0.3102
# Step 82, Loss: 2.8547, Exp_loss : 2.4866, Clip_loss ; 0.3681
# Step 83, Loss: 2.8418, Exp_loss : 2.4567, Clip_loss ; 0.3851
# Step 84, Loss: 3.0386, Exp_loss : 2.4721, Clip_loss ; 0.5666
# Step 85, Loss: 2.9052, Exp_loss : 2.4238, Clip_loss ; 0.4814
# Step 86, Loss: 2.6598, Exp_loss : 2.3862, Clip_loss ; 0.2736
# Step 87, Loss: 2.9355, Exp_loss : 2.5249, Clip_loss ; 0.4106
# Step 88, Loss: 2.7390, Exp_loss : 2.3866, Clip_loss ; 0.3525
# Step 89, Loss: 2.7671, Exp_loss : 2.3474, Clip_loss ; 0.4197
# Step 90, Loss: 2.7088, Exp_loss : 2.3345, Clip_loss ; 0.3743
# Step 91, Loss: 2.9249, Exp_loss : 2.4553, Clip_loss ; 0.4696
# Step 92, Loss: 2.8196, Exp_loss : 2.4468, Clip_loss ; 0.3728
# Step 93, Loss: 2.8508, Exp_loss : 2.4049, Clip_loss ; 0.4458
# Step 94, Loss: 2.8505, Exp_loss : 2.4234, Clip_loss ; 0.4271
# Step 95, Loss: 2.9896, Exp_loss : 2.5725, Clip_loss ; 0.4170
# Step 96, Loss: 2.7732, Exp_loss : 2.4202, Clip_loss ; 0.3530
# Step 97, Loss: 2.9133, Exp_loss : 2.4269, Clip_loss ; 0.4864
# Step 98, Loss: 2.7992, Exp_loss : 2.3761, Clip_loss ; 0.4231
# Step 99, Loss: 2.8578, Exp_loss : 2.4587, Clip_loss ; 0.3992
# Step 100, Loss: 2.8590, Exp_loss : 2.4214, Clip_loss ; 0.4376
# Checkpoint saved at steps 100
# Step 101, Loss: 3.0170, Exp_loss : 2.4302, Clip_loss ; 0.5868
# Step 102, Loss: 2.8641, Exp_loss : 2.4307, Clip_loss ; 0.4334
# Step 103, Loss: 2.9458, Exp_loss : 2.4175, Clip_loss ; 0.5283
# Step 104, Loss: 2.8513, Exp_loss : 2.3767, Clip_loss ; 0.4746
# Step 105, Loss: 2.8280, Exp_loss : 2.3798, Clip_loss ; 0.4482
# Step 106, Loss: 2.8877, Exp_loss : 2.4374, Clip_loss ; 0.4503
# Step 107, Loss: 2.9038, Exp_loss : 2.4859, Clip_loss ; 0.4179
# Step 108, Loss: 2.8269, Exp_loss : 2.4409, Clip_loss ; 0.3861
# Step 109, Loss: 2.6744, Exp_loss : 2.4165, Clip_loss ; 0.2578
# Step 110, Loss: 2.9274, Exp_loss : 2.3476, Clip_loss ; 0.5798
# Step 111, Loss: 2.7712, Exp_loss : 2.3771, Clip_loss ; 0.3941
# Step 112, Loss: 2.6112, Exp_loss : 2.3293, Clip_loss ; 0.2819
# Step 113, Loss: 2.5718, Exp_loss : 2.3031, Clip_loss ; 0.2687
# Step 114, Loss: 2.7350, Exp_loss : 2.3381, Clip_loss ; 0.3968
# Step 115, Loss: 2.6769, Exp_loss : 2.3356, Clip_loss ; 0.3412
# Step 116, Loss: 2.9735, Exp_loss : 2.5437, Clip_loss ; 0.4298
# Step 117, Loss: 2.8975, Exp_loss : 2.4586, Clip_loss ; 0.4389
# Step 118, Loss: 2.9100, Exp_loss : 2.4925, Clip_loss ; 0.4174
# Step 119, Loss: 2.8775, Exp_loss : 2.4418, Clip_loss ; 0.4356
# Step 120, Loss: 2.7192, Exp_loss : 2.3103, Clip_loss ; 0.4089
# Step 121, Loss: 3.1362, Exp_loss : 2.4424, Clip_loss ; 0.6938
# Step 122, Loss: 2.7331, Exp_loss : 2.3780, Clip_loss ; 0.3550
# Step 123, Loss: 2.8953, Exp_loss : 2.3780, Clip_loss ; 0.5173
# Step 124, Loss: 2.9398, Exp_loss : 2.4986, Clip_loss ; 0.4412
# Step 125, Loss: 2.7996, Exp_loss : 2.4186, Clip_loss ; 0.3810
# Step 126, Loss: 2.7677, Exp_loss : 2.4029, Clip_loss ; 0.3648
# Step 127, Loss: 2.9009, Exp_loss : 2.4531, Clip_loss ; 0.4478
# Step 128, Loss: 2.8835, Exp_loss : 2.4836, Clip_loss ; 0.3999
# Step 129, Loss: 2.8602, Exp_loss : 2.4462, Clip_loss ; 0.4140
# Step 130, Loss: 2.8578, Exp_loss : 2.4144, Clip_loss ; 0.4435
# Step 131, Loss: 2.7910, Exp_loss : 2.4038, Clip_loss ; 0.3872
# Step 132, Loss: 2.6993, Exp_loss : 2.4088, Clip_loss ; 0.2905
# Step 133, Loss: 2.8493, Exp_loss : 2.4873, Clip_loss ; 0.3620
# Step 134, Loss: 2.7655, Exp_loss : 2.3398, Clip_loss ; 0.4257
# Step 135, Loss: 2.9966, Exp_loss : 2.5398, Clip_loss ; 0.4568
# Step 136, Loss: 2.7800, Exp_loss : 2.3455, Clip_loss ; 0.4345
# Step 137, Loss: 2.7462, Exp_loss : 2.3348, Clip_loss ; 0.4115
# Step 138, Loss: 2.7929, Exp_loss : 2.4969, Clip_loss ; 0.2961
# Step 139, Loss: 2.7619, Exp_loss : 2.3305, Clip_loss ; 0.4314
# Step 140, Loss: 2.8022, Exp_loss : 2.3888, Clip_loss ; 0.4134
# Step 141, Loss: 2.7013, Exp_loss : 2.4037, Clip_loss ; 0.2976
# Step 142, Loss: 2.8123, Exp_loss : 2.3506, Clip_loss ; 0.4617
# Step 143, Loss: 2.7401, Exp_loss : 2.4081, Clip_loss ; 0.3320
# Step 144, Loss: 2.7661, Exp_loss : 2.3560, Clip_loss ; 0.4101
# Step 145, Loss: 3.0306, Exp_loss : 2.4396, Clip_loss ; 0.5910
# Step 146, Loss: 2.7468, Exp_loss : 2.3585, Clip_loss ; 0.3883
# Step 147, Loss: 2.7162, Exp_loss : 2.3087, Clip_loss ; 0.4075
# Step 148, Loss: 2.6127, Exp_loss : 2.3188, Clip_loss ; 0.2939
# Step 149, Loss: 2.7541, Exp_loss : 2.3980, Clip_loss ; 0.3561
# Step 150, Loss: 2.8425, Exp_loss : 2.4658, Clip_loss ; 0.3767
# Step 151, Loss: 2.8428, Exp_loss : 2.4327, Clip_loss ; 0.4101
# Step 152, Loss: 2.8569, Exp_loss : 2.3964, Clip_loss ; 0.4606
# Step 153, Loss: 2.7220, Exp_loss : 2.3362, Clip_loss ; 0.3858
# Step 154, Loss: 2.9949, Exp_loss : 2.4082, Clip_loss ; 0.5867
# Step 155, Loss: 2.7729, Exp_loss : 2.4629, Clip_loss ; 0.3100
# Step 156, Loss: 2.7969, Exp_loss : 2.4006, Clip_loss ; 0.3963
# Step 157, Loss: 2.7380, Exp_loss : 2.3710, Clip_loss ; 0.3670
# Step 158, Loss: 2.9175, Exp_loss : 2.4007, Clip_loss ; 0.5169
# Step 159, Loss: 2.9067, Exp_loss : 2.3157, Clip_loss ; 0.5910
# Step 160, Loss: 2.7382, Exp_loss : 2.2876, Clip_loss ; 0.4506
# Step 161, Loss: 2.7292, Exp_loss : 2.2947, Clip_loss ; 0.4345
# Step 162, Loss: 2.6984, Exp_loss : 2.3932, Clip_loss ; 0.3051
# Step 163, Loss: 2.7749, Exp_loss : 2.2996, Clip_loss ; 0.4753
# Step 164, Loss: 2.6678, Exp_loss : 2.3435, Clip_loss ; 0.3243
# Step 165, Loss: 2.7187, Exp_loss : 2.3402, Clip_loss ; 0.3785
# Step 166, Loss: 2.6260, Exp_loss : 2.3672, Clip_loss ; 0.2587
# Step 167, Loss: 2.7642, Exp_loss : 2.3316, Clip_loss ; 0.4326
# Step 168, Loss: 2.9284, Exp_loss : 2.4577, Clip_loss ; 0.4707
# Step 169, Loss: 2.7681, Exp_loss : 2.3629, Clip_loss ; 0.4053
# Step 170, Loss: 2.6421, Exp_loss : 2.3097, Clip_loss ; 0.3324
# Step 171, Loss: 2.5085, Exp_loss : 2.2822, Clip_loss ; 0.2263
# Step 172, Loss: 2.7499, Exp_loss : 2.4215, Clip_loss ; 0.3285
# Step 173, Loss: 2.6268, Exp_loss : 2.3509, Clip_loss ; 0.2759
# Step 174, Loss: 2.8698, Exp_loss : 2.4328, Clip_loss ; 0.4371
# Step 175, Loss: 2.8144, Exp_loss : 2.3510, Clip_loss ; 0.4634
# Step 176, Loss: 3.0229, Exp_loss : 2.4685, Clip_loss ; 0.5544
# Step 177, Loss: 2.8399, Exp_loss : 2.4400, Clip_loss ; 0.3999
# Step 178, Loss: 2.6508, Exp_loss : 2.3607, Clip_loss ; 0.2900
# Step 179, Loss: 2.9114, Exp_loss : 2.1464, Clip_loss ; 0.7650
# Finished Training
# model evaluation================================================================================
# /home/sunrui/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/transformer.py:544: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at /opt/conda/conda-bld/pytorch_1678411187366/work/aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._transformer_encoder_layer_fwd(
# avg total loss:22.4946, avg exp loss:19.6103, avg_clip_loss:2.8843
# epochs: 1 begin training:================================================================================
# Step 1, Loss: 2.5076, Exp_loss : 2.2283, Clip_loss ; 0.2794
# Step 2, Loss: 2.8697, Exp_loss : 2.4382, Clip_loss ; 0.4315
# Step 3, Loss: 2.5960, Exp_loss : 2.2989, Clip_loss ; 0.2971
# Step 4, Loss: 2.6980, Exp_loss : 2.3872, Clip_loss ; 0.3108
# Step 5, Loss: 2.8205, Exp_loss : 2.4475, Clip_loss ; 0.3730
# Step 6, Loss: 2.8958, Exp_loss : 2.4384, Clip_loss ; 0.4574
# Step 7, Loss: 2.6974, Exp_loss : 2.4088, Clip_loss ; 0.2887
# Step 8, Loss: 2.7315, Exp_loss : 2.3962, Clip_loss ; 0.3353
# Step 9, Loss: 2.7010, Exp_loss : 2.3229, Clip_loss ; 0.3782
# Step 10, Loss: 2.6358, Exp_loss : 2.4014, Clip_loss ; 0.2343
# Step 11, Loss: 2.8076, Exp_loss : 2.4119, Clip_loss ; 0.3957
# Step 12, Loss: 2.6564, Exp_loss : 2.3106, Clip_loss ; 0.3459
# Step 13, Loss: 2.7213, Exp_loss : 2.4565, Clip_loss ; 0.2647
# Step 14, Loss: 2.7843, Exp_loss : 2.3770, Clip_loss ; 0.4073
# Step 15, Loss: 2.4318, Exp_loss : 2.1357, Clip_loss ; 0.2961
# Step 16, Loss: 2.7364, Exp_loss : 2.2681, Clip_loss ; 0.4683
# Step 17, Loss: 2.6268, Exp_loss : 2.3698, Clip_loss ; 0.2570
# Step 18, Loss: 2.5970, Exp_loss : 2.3167, Clip_loss ; 0.2803
# Step 19, Loss: 2.7003, Exp_loss : 2.4128, Clip_loss ; 0.2875
# Step 20, Loss: 2.6942, Exp_loss : 2.4007, Clip_loss ; 0.2935
# Step 21, Loss: 2.7720, Exp_loss : 2.3186, Clip_loss ; 0.4535
# Step 22, Loss: 2.6699, Exp_loss : 2.3577, Clip_loss ; 0.3122
# Step 23, Loss: 2.7731, Exp_loss : 2.4438, Clip_loss ; 0.3294
# Step 24, Loss: 2.7462, Exp_loss : 2.3308, Clip_loss ; 0.4154
# Step 25, Loss: 2.8780, Exp_loss : 2.4696, Clip_loss ; 0.4084
# Step 26, Loss: 2.6097, Exp_loss : 2.3438, Clip_loss ; 0.2659
# Step 27, Loss: 2.7821, Exp_loss : 2.3916, Clip_loss ; 0.3906
# Step 28, Loss: 2.8223, Exp_loss : 2.3945, Clip_loss ; 0.4278
# Step 29, Loss: 2.7707, Exp_loss : 2.4074, Clip_loss ; 0.3633
# Step 30, Loss: 2.7841, Exp_loss : 2.4198, Clip_loss ; 0.3643
# Step 31, Loss: 2.6099, Exp_loss : 2.3207, Clip_loss ; 0.2893
# Step 32, Loss: 2.6512, Exp_loss : 2.3046, Clip_loss ; 0.3466
# Step 33, Loss: 2.6326, Exp_loss : 2.3177, Clip_loss ; 0.3149
# Step 34, Loss: 2.6367, Exp_loss : 2.2764, Clip_loss ; 0.3603
# Step 35, Loss: 2.5993, Exp_loss : 2.3285, Clip_loss ; 0.2708
# Step 36, Loss: 2.8222, Exp_loss : 2.3532, Clip_loss ; 0.4690
# Step 37, Loss: 2.9223, Exp_loss : 2.4702, Clip_loss ; 0.4521
# Step 38, Loss: 2.7010, Exp_loss : 2.2532, Clip_loss ; 0.4478
# Step 39, Loss: 2.7791, Exp_loss : 2.4166, Clip_loss ; 0.3625
# Step 40, Loss: 2.7494, Exp_loss : 2.4297, Clip_loss ; 0.3197
# Step 41, Loss: 2.8812, Exp_loss : 2.4729, Clip_loss ; 0.4084
# Step 42, Loss: 2.7351, Exp_loss : 2.3303, Clip_loss ; 0.4048
# Step 43, Loss: 2.7214, Exp_loss : 2.3854, Clip_loss ; 0.3359
# Step 44, Loss: 2.6314, Exp_loss : 2.3446, Clip_loss ; 0.2868
# Step 45, Loss: 2.7013, Exp_loss : 2.3346, Clip_loss ; 0.3667
# Step 46, Loss: 2.8517, Exp_loss : 2.3654, Clip_loss ; 0.4863
# Step 47, Loss: 2.7592, Exp_loss : 2.3436, Clip_loss ; 0.4156
# Step 48, Loss: 2.7693, Exp_loss : 2.2856, Clip_loss ; 0.4837
# Step 49, Loss: 2.8411, Exp_loss : 2.4182, Clip_loss ; 0.4229
# Step 50, Loss: 2.8660, Exp_loss : 2.4655, Clip_loss ; 0.4005
# Step 51, Loss: 2.8772, Exp_loss : 2.4436, Clip_loss ; 0.4336
# Step 52, Loss: 2.6914, Exp_loss : 2.4328, Clip_loss ; 0.2586
# Step 53, Loss: 2.7120, Exp_loss : 2.2618, Clip_loss ; 0.4502
# Step 54, Loss: 2.5886, Exp_loss : 2.2797, Clip_loss ; 0.3089
# Step 55, Loss: 2.6076, Exp_loss : 2.3127, Clip_loss ; 0.2949
# Step 56, Loss: 2.7114, Exp_loss : 2.3746, Clip_loss ; 0.3368
# Step 57, Loss: 2.6305, Exp_loss : 2.3441, Clip_loss ; 0.2864
# Step 58, Loss: 2.8095, Exp_loss : 2.4558, Clip_loss ; 0.3537
# Step 59, Loss: 2.7920, Exp_loss : 2.3767, Clip_loss ; 0.4153
# Step 60, Loss: 2.8480, Exp_loss : 2.4665, Clip_loss ; 0.3815
# Step 61, Loss: 2.8297, Exp_loss : 2.4489, Clip_loss ; 0.3807
# Step 62, Loss: 2.6661, Exp_loss : 2.3887, Clip_loss ; 0.2774
# Step 63, Loss: 2.8053, Exp_loss : 2.4254, Clip_loss ; 0.3799
# Step 64, Loss: 2.6082, Exp_loss : 2.2527, Clip_loss ; 0.3555
# Step 65, Loss: 2.5529, Exp_loss : 2.3396, Clip_loss ; 0.2134
# Step 66, Loss: 2.7463, Exp_loss : 2.4257, Clip_loss ; 0.3206
# Step 67, Loss: 2.6709, Exp_loss : 2.2875, Clip_loss ; 0.3834
# Step 68, Loss: 2.6348, Exp_loss : 2.2773, Clip_loss ; 0.3575
# Step 69, Loss: 2.6115, Exp_loss : 2.2190, Clip_loss ; 0.3926
# Step 70, Loss: 2.8898, Exp_loss : 2.3421, Clip_loss ; 0.5477
# Step 71, Loss: 2.8532, Exp_loss : 2.3620, Clip_loss ; 0.4912
# Step 72, Loss: 2.9415, Exp_loss : 2.3776, Clip_loss ; 0.5638
# Step 73, Loss: 2.7114, Exp_loss : 2.3699, Clip_loss ; 0.3415
# Step 74, Loss: 2.8599, Exp_loss : 2.3938, Clip_loss ; 0.4662
# Step 75, Loss: 2.7478, Exp_loss : 2.3236, Clip_loss ; 0.4242
# Step 76, Loss: 2.7710, Exp_loss : 2.3628, Clip_loss ; 0.4083
# Step 77, Loss: 2.8546, Exp_loss : 2.4747, Clip_loss ; 0.3798
# Step 78, Loss: 2.7070, Exp_loss : 2.3570, Clip_loss ; 0.3500
# Step 79, Loss: 2.5641, Exp_loss : 2.2992, Clip_loss ; 0.2649
# Step 80, Loss: 2.6119, Exp_loss : 2.4069, Clip_loss ; 0.2050
# Step 81, Loss: 2.6936, Exp_loss : 2.2946, Clip_loss ; 0.3990
# Step 82, Loss: 2.8724, Exp_loss : 2.4464, Clip_loss ; 0.4260
# Step 83, Loss: 2.5414, Exp_loss : 2.3169, Clip_loss ; 0.2244
# Step 84, Loss: 2.7272, Exp_loss : 2.4805, Clip_loss ; 0.2467
# Step 85, Loss: 2.7536, Exp_loss : 2.3970, Clip_loss ; 0.3566
# Step 86, Loss: 2.7965, Exp_loss : 2.4158, Clip_loss ; 0.3807
# Step 87, Loss: 2.8285, Exp_loss : 2.5093, Clip_loss ; 0.3192
# Step 88, Loss: 2.7217, Exp_loss : 2.3548, Clip_loss ; 0.3668
# Step 89, Loss: 2.6090, Exp_loss : 2.3717, Clip_loss ; 0.2373
# Step 90, Loss: 2.6683, Exp_loss : 2.3878, Clip_loss ; 0.2805
# Step 91, Loss: 2.8655, Exp_loss : 2.3717, Clip_loss ; 0.4938
# Step 92, Loss: 2.6357, Exp_loss : 2.3526, Clip_loss ; 0.2832
# Step 93, Loss: 2.8410, Exp_loss : 2.4614, Clip_loss ; 0.3796
# Step 94, Loss: 2.6653, Exp_loss : 2.3767, Clip_loss ; 0.2886
# Step 95, Loss: 2.9001, Exp_loss : 2.3849, Clip_loss ; 0.5152
# Step 96, Loss: 2.5541, Exp_loss : 2.3971, Clip_loss ; 0.1570
# Step 97, Loss: 2.6727, Exp_loss : 2.3355, Clip_loss ; 0.3373
# Step 98, Loss: 2.5963, Exp_loss : 2.3937, Clip_loss ; 0.2026
# Step 99, Loss: 2.7239, Exp_loss : 2.3602, Clip_loss ; 0.3637
# Step 100, Loss: 2.5953, Exp_loss : 2.1845, Clip_loss ; 0.4108
# Checkpoint saved at steps 100
# Step 101, Loss: 2.6450, Exp_loss : 2.3511, Clip_loss ; 0.2940
# Step 102, Loss: 2.7106, Exp_loss : 2.3668, Clip_loss ; 0.3438
# Step 103, Loss: 2.7214, Exp_loss : 2.3781, Clip_loss ; 0.3432
# Step 104, Loss: 2.8336, Exp_loss : 2.4809, Clip_loss ; 0.3527
# Step 105, Loss: 2.8084, Exp_loss : 2.4398, Clip_loss ; 0.3686
# Step 106, Loss: 2.7890, Exp_loss : 2.3875, Clip_loss ; 0.4015
# Step 107, Loss: 2.8298, Exp_loss : 2.4035, Clip_loss ; 0.4263
# Step 108, Loss: 2.6900, Exp_loss : 2.3548, Clip_loss ; 0.3352
# Step 109, Loss: 2.6429, Exp_loss : 2.2889, Clip_loss ; 0.3540
# Step 110, Loss: 2.7570, Exp_loss : 2.3727, Clip_loss ; 0.3843
# Step 111, Loss: 2.7584, Exp_loss : 2.3336, Clip_loss ; 0.4248
# Step 112, Loss: 2.8454, Exp_loss : 2.3758, Clip_loss ; 0.4696
# Step 113, Loss: 2.8347, Exp_loss : 2.3758, Clip_loss ; 0.4589
# Step 114, Loss: 2.4898, Exp_loss : 2.3322, Clip_loss ; 0.1576
# Step 115, Loss: 2.6186, Exp_loss : 2.3106, Clip_loss ; 0.3080
# Step 116, Loss: 2.6024, Exp_loss : 2.2949, Clip_loss ; 0.3075
# Step 117, Loss: 2.6291, Exp_loss : 2.3808, Clip_loss ; 0.2482
# Step 118, Loss: 2.8588, Exp_loss : 2.3504, Clip_loss ; 0.5084
# Step 119, Loss: 2.7113, Exp_loss : 2.3408, Clip_loss ; 0.3705
# Step 120, Loss: 2.6211, Exp_loss : 2.2975, Clip_loss ; 0.3236
# Step 121, Loss: 2.6558, Exp_loss : 2.4177, Clip_loss ; 0.2381
# Step 122, Loss: 2.6493, Exp_loss : 2.3016, Clip_loss ; 0.3476
# Step 123, Loss: 2.6168, Exp_loss : 2.3864, Clip_loss ; 0.2304
# Step 124, Loss: 2.7936, Exp_loss : 2.3841, Clip_loss ; 0.4095
# Step 125, Loss: 2.9075, Exp_loss : 2.4970, Clip_loss ; 0.4105
# Step 126, Loss: 2.7471, Exp_loss : 2.2748, Clip_loss ; 0.4723
# Step 127, Loss: 2.9506, Exp_loss : 2.5226, Clip_loss ; 0.4280
# Step 128, Loss: 2.6624, Exp_loss : 2.3451, Clip_loss ; 0.3173
# Step 129, Loss: 2.8113, Exp_loss : 2.4353, Clip_loss ; 0.3761
# Step 130, Loss: 2.5934, Exp_loss : 2.2758, Clip_loss ; 0.3176
# Step 131, Loss: 2.7812, Exp_loss : 2.3603, Clip_loss ; 0.4209
# Step 132, Loss: 2.6451, Exp_loss : 2.3108, Clip_loss ; 0.3343
# Step 133, Loss: 2.9070, Exp_loss : 2.4650, Clip_loss ; 0.4420
# Step 134, Loss: 2.6249, Exp_loss : 2.3457, Clip_loss ; 0.2793
# Step 135, Loss: 2.6495, Exp_loss : 2.2659, Clip_loss ; 0.3836
# Step 136, Loss: 2.8743, Exp_loss : 2.3653, Clip_loss ; 0.5090
# Step 137, Loss: 2.5595, Exp_loss : 2.3013, Clip_loss ; 0.2582
# Step 138, Loss: 2.8243, Exp_loss : 2.4221, Clip_loss ; 0.4022
# Step 139, Loss: 2.6439, Exp_loss : 2.2616, Clip_loss ; 0.3823
# Step 140, Loss: 2.5810, Exp_loss : 2.3032, Clip_loss ; 0.2778
# Step 141, Loss: 2.7272, Exp_loss : 2.4363, Clip_loss ; 0.2909
# Step 142, Loss: 2.7432, Exp_loss : 2.4025, Clip_loss ; 0.3407
# Step 143, Loss: 2.4836, Exp_loss : 2.2723, Clip_loss ; 0.2113
# Step 144, Loss: 2.6520, Exp_loss : 2.3988, Clip_loss ; 0.2532
# Step 145, Loss: 2.6399, Exp_loss : 2.3365, Clip_loss ; 0.3033
# Step 146, Loss: 2.6556, Exp_loss : 2.3228, Clip_loss ; 0.3329
# Step 147, Loss: 2.6253, Exp_loss : 2.4036, Clip_loss ; 0.2217
# Step 148, Loss: 2.7326, Exp_loss : 2.3325, Clip_loss ; 0.4001
# Step 149, Loss: 2.8470, Exp_loss : 2.4459, Clip_loss ; 0.4011
# Step 150, Loss: 2.6856, Exp_loss : 2.4053, Clip_loss ; 0.2804
# Step 151, Loss: 2.7190, Exp_loss : 2.3354, Clip_loss ; 0.3837
# Step 152, Loss: 2.8109, Exp_loss : 2.4823, Clip_loss ; 0.3286
# Step 153, Loss: 2.6092, Exp_loss : 2.3835, Clip_loss ; 0.2257
# Step 154, Loss: 2.5707, Exp_loss : 2.3725, Clip_loss ; 0.1982
# Step 155, Loss: 2.8368, Exp_loss : 2.3630, Clip_loss ; 0.4737
# Step 156, Loss: 2.5108, Exp_loss : 2.3116, Clip_loss ; 0.1992
# Step 157, Loss: 2.4886, Exp_loss : 2.2875, Clip_loss ; 0.2012
# Step 158, Loss: 2.7794, Exp_loss : 2.2973, Clip_loss ; 0.4821
# Step 159, Loss: 2.7345, Exp_loss : 2.4762, Clip_loss ; 0.2584
# Step 160, Loss: 2.6424, Exp_loss : 2.4092, Clip_loss ; 0.2331
# Step 161, Loss: 2.5460, Exp_loss : 2.2823, Clip_loss ; 0.2637
# Step 162, Loss: 2.7809, Exp_loss : 2.3440, Clip_loss ; 0.4369
# Step 163, Loss: 2.6115, Exp_loss : 2.3620, Clip_loss ; 0.2495
# Step 164, Loss: 2.6548, Exp_loss : 2.3544, Clip_loss ; 0.3004
# Step 165, Loss: 2.6442, Exp_loss : 2.2847, Clip_loss ; 0.3594
# Step 166, Loss: 2.7514, Exp_loss : 2.3478, Clip_loss ; 0.4036
# Step 167, Loss: 2.6383, Exp_loss : 2.3239, Clip_loss ; 0.3144
# Step 168, Loss: 2.7211, Exp_loss : 2.4003, Clip_loss ; 0.3208
# Step 169, Loss: 2.8668, Exp_loss : 2.4364, Clip_loss ; 0.4304
# Step 170, Loss: 2.6705, Exp_loss : 2.3831, Clip_loss ; 0.2874
# Step 171, Loss: 2.5938, Exp_loss : 2.3651, Clip_loss ; 0.2287
# Step 172, Loss: 2.6121, Exp_loss : 2.3702, Clip_loss ; 0.2419
# Step 173, Loss: 2.6209, Exp_loss : 2.3867, Clip_loss ; 0.2342
# Step 174, Loss: 2.6901, Exp_loss : 2.3806, Clip_loss ; 0.3095
# Step 175, Loss: 2.7857, Exp_loss : 2.3716, Clip_loss ; 0.4142
# Step 176, Loss: 2.5914, Exp_loss : 2.3325, Clip_loss ; 0.2588
# Step 177, Loss: 2.5430, Exp_loss : 2.3055, Clip_loss ; 0.2375
# Step 178, Loss: 2.6482, Exp_loss : 2.3119, Clip_loss ; 0.3363
# Step 179, Loss: 3.0177, Exp_loss : 2.5981, Clip_loss ; 0.4195
# Finished Training
# model evaluation================================================================================
# avg total loss:21.9030, avg exp loss:19.4838, avg_clip_loss:2.4192
# epochs: 2 begin training:================================================================================
# Step 1, Loss: 2.5614, Exp_loss : 2.3368, Clip_loss ; 0.2246
# Step 2, Loss: 2.6426, Exp_loss : 2.3817, Clip_loss ; 0.2609
# Step 3, Loss: 2.6032, Exp_loss : 2.3083, Clip_loss ; 0.2949
# Step 4, Loss: 2.7057, Exp_loss : 2.4223, Clip_loss ; 0.2834
# Step 5, Loss: 2.6290, Exp_loss : 2.4385, Clip_loss ; 0.1905
# Step 6, Loss: 2.7496, Exp_loss : 2.3946, Clip_loss ; 0.3550
# Step 7, Loss: 2.6152, Exp_loss : 2.3613, Clip_loss ; 0.2538
# Step 8, Loss: 2.6544, Exp_loss : 2.3597, Clip_loss ; 0.2947
# Step 9, Loss: 2.7575, Exp_loss : 2.3435, Clip_loss ; 0.4141
# Step 10, Loss: 2.7718, Exp_loss : 2.3933, Clip_loss ; 0.3784
# Step 11, Loss: 2.7466, Exp_loss : 2.4361, Clip_loss ; 0.3104
# Step 12, Loss: 2.7010, Exp_loss : 2.3480, Clip_loss ; 0.3530
# Step 13, Loss: 2.8022, Exp_loss : 2.4272, Clip_loss ; 0.3750
# Step 14, Loss: 2.5864, Exp_loss : 2.3200, Clip_loss ; 0.2664
# Step 15, Loss: 2.7406, Exp_loss : 2.4199, Clip_loss ; 0.3207
# Step 16, Loss: 2.5537, Exp_loss : 2.2020, Clip_loss ; 0.3517
# Step 17, Loss: 2.5680, Exp_loss : 2.3404, Clip_loss ; 0.2276
# Step 18, Loss: 2.8502, Exp_loss : 2.3621, Clip_loss ; 0.4881
# Step 19, Loss: 2.6706, Exp_loss : 2.4401, Clip_loss ; 0.2305
# Step 20, Loss: 2.5961, Exp_loss : 2.3074, Clip_loss ; 0.2887
# Step 21, Loss: 2.6692, Exp_loss : 2.3340, Clip_loss ; 0.3351
# Step 22, Loss: 2.6774, Exp_loss : 2.3581, Clip_loss ; 0.3193
# Step 23, Loss: 2.5577, Exp_loss : 2.3454, Clip_loss ; 0.2123
# Step 24, Loss: 2.7029, Exp_loss : 2.4088, Clip_loss ; 0.2940
# Step 25, Loss: 2.5728, Exp_loss : 2.2884, Clip_loss ; 0.2844
# Step 26, Loss: 2.8245, Exp_loss : 2.4520, Clip_loss ; 0.3725
# Step 27, Loss: 2.5343, Exp_loss : 2.3179, Clip_loss ; 0.2164
# Step 28, Loss: 2.6229, Exp_loss : 2.3166, Clip_loss ; 0.3063
# Step 29, Loss: 2.7194, Exp_loss : 2.3583, Clip_loss ; 0.3611
# Step 30, Loss: 2.7337, Exp_loss : 2.4064, Clip_loss ; 0.3273
# Step 31, Loss: 2.7680, Exp_loss : 2.3466, Clip_loss ; 0.4214
# Step 32, Loss: 2.6479, Exp_loss : 2.2913, Clip_loss ; 0.3565
# Step 33, Loss: 2.7498, Exp_loss : 2.3723, Clip_loss ; 0.3774
# Step 34, Loss: 2.7392, Exp_loss : 2.3827, Clip_loss ; 0.3565
# Step 35, Loss: 2.7079, Exp_loss : 2.3665, Clip_loss ; 0.3414
# Step 36, Loss: 2.5686, Exp_loss : 2.3063, Clip_loss ; 0.2623
# Step 37, Loss: 2.9120, Exp_loss : 2.4062, Clip_loss ; 0.5058
# Step 38, Loss: 2.6359, Exp_loss : 2.3406, Clip_loss ; 0.2953
# Step 39, Loss: 2.6354, Exp_loss : 2.3018, Clip_loss ; 0.3336
# Step 40, Loss: 2.5812, Exp_loss : 2.3250, Clip_loss ; 0.2562
# Step 41, Loss: 2.7952, Exp_loss : 2.4549, Clip_loss ; 0.3403
# Step 42, Loss: 2.7199, Exp_loss : 2.3002, Clip_loss ; 0.4197
# Step 43, Loss: 2.7625, Exp_loss : 2.3617, Clip_loss ; 0.4008
# Step 44, Loss: 2.5701, Exp_loss : 2.3157, Clip_loss ; 0.2544
# Step 45, Loss: 2.6828, Exp_loss : 2.3420, Clip_loss ; 0.3408
# Step 46, Loss: 2.7273, Exp_loss : 2.3615, Clip_loss ; 0.3657
# Step 47, Loss: 2.5861, Exp_loss : 2.3367, Clip_loss ; 0.2494
# Step 48, Loss: 2.7741, Exp_loss : 2.3602, Clip_loss ; 0.4139
# Step 49, Loss: 2.6720, Exp_loss : 2.3660, Clip_loss ; 0.3060
# Step 50, Loss: 2.7348, Exp_loss : 2.4045, Clip_loss ; 0.3303
# Step 51, Loss: 2.6480, Exp_loss : 2.3064, Clip_loss ; 0.3417
# Step 52, Loss: 2.8661, Exp_loss : 2.4836, Clip_loss ; 0.3825
# Step 53, Loss: 2.7587, Exp_loss : 2.4382, Clip_loss ; 0.3205
# Step 54, Loss: 2.6495, Exp_loss : 2.4238, Clip_loss ; 0.2257
# Step 55, Loss: 2.6010, Exp_loss : 2.3751, Clip_loss ; 0.2259
# Step 56, Loss: 2.7054, Exp_loss : 2.3659, Clip_loss ; 0.3395
# Step 57, Loss: 2.5795, Exp_loss : 2.3896, Clip_loss ; 0.1899
# Step 58, Loss: 2.4069, Exp_loss : 2.2441, Clip_loss ; 0.1628
# Step 59, Loss: 2.6058, Exp_loss : 2.3820, Clip_loss ; 0.2239
# Step 60, Loss: 2.4742, Exp_loss : 2.1937, Clip_loss ; 0.2805
# Step 61, Loss: 2.9098, Exp_loss : 2.3822, Clip_loss ; 0.5276
# Step 62, Loss: 2.7027, Exp_loss : 2.3719, Clip_loss ; 0.3307
# Step 63, Loss: 2.9636, Exp_loss : 2.4623, Clip_loss ; 0.5013
# Step 64, Loss: 2.6441, Exp_loss : 2.3805, Clip_loss ; 0.2636
# Step 65, Loss: 2.6447, Exp_loss : 2.3342, Clip_loss ; 0.3104
# Step 66, Loss: 2.6970, Exp_loss : 2.4204, Clip_loss ; 0.2767
# Step 67, Loss: 2.6585, Exp_loss : 2.3702, Clip_loss ; 0.2882
# Step 68, Loss: 2.5830, Exp_loss : 2.2402, Clip_loss ; 0.3427
# Step 69, Loss: 2.6510, Exp_loss : 2.3675, Clip_loss ; 0.2835
# Step 70, Loss: 2.5395, Exp_loss : 2.3178, Clip_loss ; 0.2217
# Step 71, Loss: 2.7337, Exp_loss : 2.4419, Clip_loss ; 0.2918
# Step 72, Loss: 2.4941, Exp_loss : 2.2314, Clip_loss ; 0.2627
# Step 73, Loss: 2.6568, Exp_loss : 2.2225, Clip_loss ; 0.4343
# Step 74, Loss: 2.4895, Exp_loss : 2.3224, Clip_loss ; 0.1671
# Step 75, Loss: 2.7486, Exp_loss : 2.2828, Clip_loss ; 0.4658
# Step 76, Loss: 2.5385, Exp_loss : 2.2945, Clip_loss ; 0.2439
# Step 77, Loss: 2.6005, Exp_loss : 2.2366, Clip_loss ; 0.3639
# Step 78, Loss: 2.6622, Exp_loss : 2.3531, Clip_loss ; 0.3091
# Step 79, Loss: 2.6077, Exp_loss : 2.4258, Clip_loss ; 0.1819
# Step 80, Loss: 2.5191, Exp_loss : 2.3381, Clip_loss ; 0.1809
# Step 81, Loss: 2.5465, Exp_loss : 2.2608, Clip_loss ; 0.2857
# Step 82, Loss: 2.8446, Exp_loss : 2.4698, Clip_loss ; 0.3749
# Step 83, Loss: 2.7495, Exp_loss : 2.3750, Clip_loss ; 0.3744
# Step 84, Loss: 2.8736, Exp_loss : 2.3866, Clip_loss ; 0.4870
# Step 85, Loss: 2.5561, Exp_loss : 2.3512, Clip_loss ; 0.2049
# Step 86, Loss: 2.5063, Exp_loss : 2.2500, Clip_loss ; 0.2563
# Step 87, Loss: 2.7271, Exp_loss : 2.3529, Clip_loss ; 0.3742
# Step 88, Loss: 2.6173, Exp_loss : 2.3297, Clip_loss ; 0.2876
# Step 89, Loss: 2.5170, Exp_loss : 2.2338, Clip_loss ; 0.2833
# Step 90, Loss: 2.6362, Exp_loss : 2.2349, Clip_loss ; 0.4013
# Step 91, Loss: 2.6478, Exp_loss : 2.3656, Clip_loss ; 0.2821
# Step 92, Loss: 2.7435, Exp_loss : 2.3840, Clip_loss ; 0.3594
# Step 93, Loss: 2.5412, Exp_loss : 2.3594, Clip_loss ; 0.1818
# Step 94, Loss: 2.6562, Exp_loss : 2.3446, Clip_loss ; 0.3116
# Step 95, Loss: 2.7277, Exp_loss : 2.4171, Clip_loss ; 0.3106
# Step 96, Loss: 2.7912, Exp_loss : 2.4508, Clip_loss ; 0.3405
# Step 97, Loss: 2.6467, Exp_loss : 2.3822, Clip_loss ; 0.2645
# Step 98, Loss: 2.6962, Exp_loss : 2.4365, Clip_loss ; 0.2597
# Step 99, Loss: 2.5483, Exp_loss : 2.2437, Clip_loss ; 0.3046
# Step 100, Loss: 2.6814, Exp_loss : 2.3547, Clip_loss ; 0.3267
# Checkpoint saved at steps 100
# Step 101, Loss: 2.6985, Exp_loss : 2.3439, Clip_loss ; 0.3545
# Step 102, Loss: 2.7887, Exp_loss : 2.4819, Clip_loss ; 0.3068
# Step 103, Loss: 2.7202, Exp_loss : 2.2409, Clip_loss ; 0.4793
# Step 104, Loss: 2.8242, Exp_loss : 2.4706, Clip_loss ; 0.3536
# Step 105, Loss: 2.5449, Exp_loss : 2.2837, Clip_loss ; 0.2612
# Step 106, Loss: 2.7825, Exp_loss : 2.3960, Clip_loss ; 0.3865
# Step 107, Loss: 2.8017, Exp_loss : 2.3880, Clip_loss ; 0.4137
# Step 108, Loss: 2.7088, Exp_loss : 2.4289, Clip_loss ; 0.2799
# Step 109, Loss: 2.4979, Exp_loss : 2.2174, Clip_loss ; 0.2805
# Step 110, Loss: 2.5749, Exp_loss : 2.3597, Clip_loss ; 0.2152
# Step 111, Loss: 2.6415, Exp_loss : 2.3114, Clip_loss ; 0.3302
# Step 112, Loss: 2.5559, Exp_loss : 2.3436, Clip_loss ; 0.2123
# Step 113, Loss: 2.6861, Exp_loss : 2.2595, Clip_loss ; 0.4266
# Step 114, Loss: 2.6496, Exp_loss : 2.3270, Clip_loss ; 0.3225
# Step 115, Loss: 2.7599, Exp_loss : 2.4876, Clip_loss ; 0.2723
# Step 116, Loss: 2.5521, Exp_loss : 2.3558, Clip_loss ; 0.1962
# Step 117, Loss: 2.6612, Exp_loss : 2.3175, Clip_loss ; 0.3438
# Step 118, Loss: 2.8946, Exp_loss : 2.4425, Clip_loss ; 0.4521
# Step 119, Loss: 2.7963, Exp_loss : 2.4718, Clip_loss ; 0.3246
# Step 120, Loss: 2.6299, Exp_loss : 2.4904, Clip_loss ; 0.1396
# Step 121, Loss: 2.5957, Exp_loss : 2.2974, Clip_loss ; 0.2983
# Step 122, Loss: 2.5466, Exp_loss : 2.3329, Clip_loss ; 0.2136
# Step 123, Loss: 2.7884, Exp_loss : 2.4523, Clip_loss ; 0.3361
# Step 124, Loss: 2.5723, Exp_loss : 2.4591, Clip_loss ; 0.1132
# Step 125, Loss: 2.7485, Exp_loss : 2.4330, Clip_loss ; 0.3155
# Step 126, Loss: 2.6328, Exp_loss : 2.2556, Clip_loss ; 0.3772
# Step 127, Loss: 2.5616, Exp_loss : 2.2515, Clip_loss ; 0.3101
# Step 128, Loss: 2.6427, Exp_loss : 2.3308, Clip_loss ; 0.3119
# Step 129, Loss: 2.7178, Exp_loss : 2.3566, Clip_loss ; 0.3612
# Step 130, Loss: 2.6377, Exp_loss : 2.3779, Clip_loss ; 0.2598
# Step 131, Loss: 2.6632, Exp_loss : 2.3973, Clip_loss ; 0.2658
# Step 132, Loss: 2.5911, Exp_loss : 2.3830, Clip_loss ; 0.2081
# Step 133, Loss: 2.8821, Exp_loss : 2.4331, Clip_loss ; 0.4490
# Step 134, Loss: 2.3942, Exp_loss : 2.2436, Clip_loss ; 0.1505
# Step 135, Loss: 2.6557, Exp_loss : 2.3920, Clip_loss ; 0.2637
# Step 136, Loss: 2.6000, Exp_loss : 2.4181, Clip_loss ; 0.1818
# Step 137, Loss: 2.6176, Exp_loss : 2.3099, Clip_loss ; 0.3077
# Step 138, Loss: 2.7559, Exp_loss : 2.4023, Clip_loss ; 0.3536
# Step 139, Loss: 2.7469, Exp_loss : 2.3740, Clip_loss ; 0.3729
# Step 140, Loss: 2.7922, Exp_loss : 2.4415, Clip_loss ; 0.3507
# Step 141, Loss: 2.5758, Exp_loss : 2.3990, Clip_loss ; 0.1769
# Step 142, Loss: 2.5492, Exp_loss : 2.3093, Clip_loss ; 0.2399
# Step 143, Loss: 2.6203, Exp_loss : 2.2487, Clip_loss ; 0.3715
# Step 144, Loss: 2.6578, Exp_loss : 2.3602, Clip_loss ; 0.2975
# Step 145, Loss: 2.6702, Exp_loss : 2.3870, Clip_loss ; 0.2832
# Step 146, Loss: 2.6023, Exp_loss : 2.3255, Clip_loss ; 0.2768
# Step 147, Loss: 2.7403, Exp_loss : 2.4163, Clip_loss ; 0.3240
# Step 148, Loss: 2.4748, Exp_loss : 2.2540, Clip_loss ; 0.2208
# Step 149, Loss: 2.5812, Exp_loss : 2.2855, Clip_loss ; 0.2957
# Step 150, Loss: 2.5561, Exp_loss : 2.3325, Clip_loss ; 0.2236
# Step 151, Loss: 2.8130, Exp_loss : 2.4228, Clip_loss ; 0.3902
# Step 152, Loss: 2.6479, Exp_loss : 2.3808, Clip_loss ; 0.2671
# Step 153, Loss: 2.6341, Exp_loss : 2.4256, Clip_loss ; 0.2084
# Step 154, Loss: 2.7197, Exp_loss : 2.3076, Clip_loss ; 0.4121
# Step 155, Loss: 2.6019, Exp_loss : 2.2473, Clip_loss ; 0.3547
# Step 156, Loss: 2.7504, Exp_loss : 2.4579, Clip_loss ; 0.2926
# Step 157, Loss: 2.5518, Exp_loss : 2.3509, Clip_loss ; 0.2009
# Step 158, Loss: 2.5731, Exp_loss : 2.3274, Clip_loss ; 0.2457
# Step 159, Loss: 2.6007, Exp_loss : 2.3311, Clip_loss ; 0.2695
# Step 160, Loss: 2.6441, Exp_loss : 2.3758, Clip_loss ; 0.2682
# Step 161, Loss: 2.8239, Exp_loss : 2.4235, Clip_loss ; 0.4004
# Step 162, Loss: 2.7066, Exp_loss : 2.3643, Clip_loss ; 0.3423
# Step 163, Loss: 2.6665, Exp_loss : 2.4024, Clip_loss ; 0.2641
# Step 164, Loss: 2.8098, Exp_loss : 2.4265, Clip_loss ; 0.3833
# Step 165, Loss: 2.5714, Exp_loss : 2.2889, Clip_loss ; 0.2826
# Step 166, Loss: 2.7250, Exp_loss : 2.3342, Clip_loss ; 0.3909
# Step 167, Loss: 2.6364, Exp_loss : 2.3474, Clip_loss ; 0.2890
# Step 168, Loss: 2.7293, Exp_loss : 2.4600, Clip_loss ; 0.2692
# Step 169, Loss: 2.5331, Exp_loss : 2.2502, Clip_loss ; 0.2828
# Step 170, Loss: 2.6692, Exp_loss : 2.2850, Clip_loss ; 0.3841
# Step 171, Loss: 2.6823, Exp_loss : 2.3104, Clip_loss ; 0.3719
# Step 172, Loss: 2.4495, Exp_loss : 2.2929, Clip_loss ; 0.1566
# Step 173, Loss: 2.6291, Exp_loss : 2.3277, Clip_loss ; 0.3014
# Step 174, Loss: 2.5902, Exp_loss : 2.3074, Clip_loss ; 0.2828
# Step 175, Loss: 2.8753, Exp_loss : 2.5058, Clip_loss ; 0.3695
# Step 176, Loss: 2.5049, Exp_loss : 2.2430, Clip_loss ; 0.2618
# Step 177, Loss: 2.6921, Exp_loss : 2.4331, Clip_loss ; 0.2590
# Step 178, Loss: 2.4351, Exp_loss : 2.2668, Clip_loss ; 0.1683
# Step 179, Loss: 2.4081, Exp_loss : 2.3665, Clip_loss ; 0.0416
# Finished Training
# model evaluation================================================================================
# avg total loss:21.6180, avg exp loss:19.3546, avg_clip_loss:2.2635
# epochs: 3 begin training:================================================================================
# Step 1, Loss: 2.6566, Exp_loss : 2.3632, Clip_loss ; 0.2934
# Step 2, Loss: 2.5094, Exp_loss : 2.3136, Clip_loss ; 0.1958
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 pretrain_loss = loss.pretrain_loss()
# ----> 3 my_model = train.train_multi_epoch(my_model,
#       4                 train_loader,
#       5                 test_loader,
#       6                 pretrain_loss,
#       7                 optimizer = optim.SGD(my_model.parameters(), lr=1e-4, momentum=0.9),
#       8                 device = 'cuda',
#       9                 gradient_accumulation_steps = 8,
#      10                 save_steps = 100,
#      11                 save_dir = 'test_1',
#      12                 epochs = 5)
#
# File /work/sunrui/pretrain_project/notebook/../code/train.py:171, in train_multi_epoch(model, train_loader, eval_loader, criterion, optimizer, device, gradient_accumulation_steps, save_steps, save_dir, epochs)
#     168 print(f'epochs: {i} begin training:' + '===='*20)
#     170 epoch_dir = os.path.join(save_dir,f'epoch_{i}')
# --> 171 model = train_one_epoch(model,
#     172                         train_loader,
#     173                         criterion,
#     174                         optimizer,
#     175                         device,
#     176                         gradient_accumulation_steps,
#     177                         save_steps,
#     178                         save_dir = epoch_dir)
#     180 print(f'model evaluation' + '===='*20)
#     182 (avg_total_loss, avg_exp_loss, avg_clip_loss) = eval_one_epoch(model,
#     183                                                                eval_loader,
#     184                                                                criterion,
#     185                                                                device,
#     186                                                                save_dir = epoch_dir)
#
# File /work/sunrui/pretrain_project/notebook/../code/train.py:48, in train_one_epoch(model, train_loader, criterion, optimizer, device, gradient_accumulation_steps, save_steps, save_dir)
#      44 accumulated_samples += N*2
#      47 # 反向传播
# ---> 48 total_loss.backward()
#      50 # 梯度累积
#      51 if (i + 1) % gradient_accumulation_steps == 0:
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"Device {i}: {torch.cuda.get_device_name(i)}")
# Out:
# Device 0: NVIDIA RTX A6000
# Device 1: NVIDIA RTX A6000
